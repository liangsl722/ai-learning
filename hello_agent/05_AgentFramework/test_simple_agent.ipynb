# %% [markdown]
# 测试 my_simple_agent.py

# %%
# 修改此.ipynb的工作目录
import os
os.chdir(r"C:\Users\61075\PycharmProjects\learning\hello_agent\05_AgentFramework")

print(os.getcwd())
# Out:
# C:\Users\61075\PycharmProjects\learning\hello_agent\05_AgentFramework

# %%
from dotenv import load_dotenv
load_dotenv()

from hello_agents import HelloAgentsLLM, ToolRegistry
from hello_agents.tools import CalculatorTool
from my_simple_agent import MySimpleAgent

# %%
llm = HelloAgentsLLM()

# %%
# 测试1:基础对话Agent（无工具）
print("=== 测试1:基础对话 ===")
basic_agent = MySimpleAgent(
    name="基础助手",
    llm=llm,
    system_prompt="你是一个友好的AI助手，请用简洁明了的方式回答问题。"
)

response1 = basic_agent.run("你好，请介绍一下自己")
print(f"基础对话响应: {response1}\n")
# Out:
# === 测试1:基础对话 ===
# ✅ 基础助手 初始化完成，工具调用：禁用
# 🤖 基础助手 正在处理：你好，请介绍一下自己
# ✅ 基础助手 响应完成
# 基础对话响应: 你好，我是你的AI助手。我可以帮助你回答问题，提供信息，并进行简单的对话。我的目标是提供简洁和准确的回答，以帮助你解决问题或满足你的需求。有什么可以我帮忙的吗？

# %%
# 测试2:带工具的Agent
print("=== 测试2:工具增强对话 ===")
tool_registry = ToolRegistry()
calculator = CalculatorTool()
tool_registry.register_tool(calculator)

enhanced_agent = MySimpleAgent(
    name="增强助手",
    llm=llm,
    system_prompt="你是一个智能助手，可以使用工具来帮助用户。",
    tool_registry=tool_registry,
    enable_tool_calling=True
)

response2 = enhanced_agent.run("请帮我计算 15 * 8 + 32")
print(f"工具增强响应: {response2}\n")
# Out:
# === 测试2:工具增强对话 ===
# ✅ 工具 'python_calculator' 已注册。
# ✅ 增强助手 初始化完成，工具调用：启用
# 🤖 增强助手 正在处理：请帮我计算 15 * 8 + 32
# 🔧 检测到 1 个工具调用
# 🧮 正在计算: 15 * 8 + 32
# ✅ 计算结果: 152
# ✅ 增强助手 响应完成
# 工具增强响应: 计算结果是152。

# %%
# 测试3:流式响应
print("=== 测试3:流式响应 ===")
print("流式响应: ", end="")
for chunk in basic_agent.stream_run("请解释什么是人工智能"):
    pass  # 内容已在stream_run中实时打印
# Out:
# === 测试3:流式响应 ===
# 流式响应: 🌊 基础助手 开始流式处理: 请解释什么是人工智能
# 📝 实时响应: 人工智能（AI）是指使用计算机系统模拟人类智能的行为和思维过程。它涉及创建能够执行通常需要人类智慧、知识、推理和解决问题能力的任务的机器。
#
# 人工智能包括以下几个关键要素：
#
# 1. **机器学习**：让机器能够从数据中学习和改进。
# 2. **自然语言处理**：让机器能够理解和生成人类语言。
# 3. **计算机视觉**：让机器能够看到和理解图像和视频。
# 4. **推理和决策**：让机器能够根据规则和逻辑做出决定。
#
# 人工智能的目标是创建能够像人类一样思考、学习和行动的机器。它可以应用于各个领域，如：
#
# 1. **虚拟助手**：如Siri、Google Assistant等。
# 2. **图像识别**：如脸部识别、物体识别等。
# 3. **自动驾驶**：如无人驾驶汽车等。
# 4. **医疗诊断**：如辅助医生诊断疾病等。
# 5. **服务机器人**：如客服聊天机器人等。
#
# 人工智能有两种类型：
#
# 1. **狭义人工智能**：专注于特定任务的机器，例如图像识别、语音识别等。
# 2. **广义人工智能**：能够像人类一样思考和行动的机器，目前还处于理论阶段。
#
# 总之，人工智能是使用计算机系统模拟人类智能的行为和思维过程，旨在创建能够执行复杂任务的机器，并在各个领域提高效率和准确性。
# ✅ 基础助手 流式响应完成

# %%
# 测试4:动态添加工具
print("\n=== 测试4:动态工具管理 ===")
print(f"添加工具前: {basic_agent.has_tools()}")
basic_agent.add_tool(calculator)
print(f"添加工具后: {basic_agent.has_tools()}")
print(f"可用工具: {basic_agent.list_tools()}")

# 查看对话历史
print(f"\n对话历史: {len(basic_agent.get_history())} 条消息")
# Out:
# === 测试4:动态工具管理 ===
# 添加工具前: False
# ✅ 工具 'python_calculator' 已注册。
# 🔧 工具 'python_calculator' 已添加
# 添加工具后: True
# 可用工具: ['python_calculator']
#
# 对话历史: 2 条消息
