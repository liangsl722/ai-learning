# %% [markdown]
# iterative:
# - 初始prompt
# - 限制长度（words/sentences/characters）
# - 说明侧重方面、细节
# - 指定输出格式

# %%
import os
import openai
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# %%
def get_completion(prompt):
    message = [{"role": "user", "content": prompt}]

    client = openai.OpenAI(
        base_url=os.getenv("OLLAMA_BASE_URL"),
        api_key="ollama",
    )

    response = client.chat.completions.create(
        model=os.getenv("MODEL_NAME"),
        messages=message,
        temperature=0,
    )
    return response.choices[0].message.content

# %%
### 产品说明书

fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture, including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100) or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black, gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities:
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.

SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
### 初始提示词

prompt = f"""
Your task is to help a marketing team create a description for a retail website of a product based on a technical fact sheet.

Write a product description based on the information provided in the technical specifications delimited by triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Introducing the Mid-Century Inspired Office Chair from our beautiful family of furniture, perfect for enhancing any home or business setting. This stylish and functional chair is crafted with a blend of modern design and classic mid-century aesthetics, making it an ideal addition to your office space.
#
# **Design & Options:**
# Choose from several shell color options paired with various base finishes—stainless steel, matte black, gloss white, or chrome—to match any decor. The chair comes in two upholstery styles: SWC-100 with plastic back and front upholstery in 10 fabric choices and 6 leather options, or the more luxurious SWC-110 fully upholstered version.
#
# **Comfort & Ergonomics:**
# Experience unparalleled comfort with seat foam densities of medium (1.8 lb/ft3) or high (2.8 lb/ft3), ensuring a perfect fit for your body. Armrests are available in 8 positions, providing support and flexibility to suit your needs. The chair is also equipped with soft or hard-floor caster options, making it easy to move around.
#
# **Construction & Dimensions:**
# Built on a robust 5-wheel plastic-coated aluminum base that glides smoothly across any surface. The pneumatic adjustment mechanism allows for effortless height changes, ensuring you can find the perfect seating position every time. With dimensions of 53 cm (width) x 51 cm (depth) x 80 cm (height), and a seat depth of 41 cm, this chair is designed to provide ample comfort.
#
# **Versatility & Durability:**
# Crafted from high-quality materials including cast aluminum with a modified nylon PA6/PA66 coating for durability and HD36 foam for exceptional seating experience. The chair is suitable for both home and business settings and is qualified for contract use, making it ideal for professional environments as well.
#
# Elevate your workspace with this stylish and functional mid-century inspired office chair from our collection. Whether you're working from home or in a bustling office environment, this chair promises comfort, style, and durability to keep you productive throughout the day.

# %%
### 限制生成长度

prompt = f"""
Your task is to help a marketing team create a description for a retail website of a product based on a technical fact sheet.

Write a product description based on the information provided in the technical specifications delimited by triple backticks.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Elevate your workspace with the mid-century inspired SWC-100 chair. Available in multiple colors, fabrics, and armrest options, perfect for both home and business settings. Italian craftsmanship ensures durability and comfort.

# %%
len(response.split(" "))
# Out:
# 30

# %%
### 处理侧重方面，材质

prompt = f"""
Your task is to help a marketing team create a description for a retail website of a product based on a technical fact sheet.

Write a product description based on the information provided in the technical specifications delimited by triple backticks.

The description is intended for furniture retailers, so should be technical in nature and focus on the materials the product is constructed from.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Crafted from cast aluminum shell with a durable PA6/PA66 coating and upholstered in high-quality HD36 foam, this mid-century inspired office chair offers versatile base finishes and seat options for both home and business settings.

# %%
### 处理侧重方面，进一步末尾包括产品ID

prompt = f"""
Your task is to help a marketing team create a description for a retail website of a product based on a technical fact sheet.

Write a product description based on the information provided in the technical specifications delimited by triple backticks.

The description is intended for furniture retailers, so should be technical in nature and focus on the materials the product is constructed from.

At the end of the description, include every 7-characters Product ID in the technical specifications.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Crafted from cast aluminum shell with a durable PA6/PA66 coating and upholstered in high-quality HD36 foam, this mid-century inspired office chair is available in multiple base finishes and upholstery options. Product IDs: SWC-100, SWC-110.

# %%
### 提取信息并输出成表格，指定表格格式

prompt = f"""
Your task is to help a marketing team create a description for a retail website of a product based on a technical fact sheet.

Write a product description based on the information provided in the technical specifications delimited by triple backticks.

The description is intended for furniture retailers, so should be technical in nature and focus on the materials the product is constructed from.

At the end of the description, include every 7-characters Product ID in the technical specifications.

After the description, include a table that gives the product's dimensions. \
The table should have two columns. In the first column include the name of the dimension. \
In the second column include the measurements oin inches only.

Give the table the title 'Product Dimensions'

Format everything as HTML that can be used in a website.
Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)

from IPython.display import display, HTML
display(HTML(response))
# Out:
# ```html
# <div>
#     <h2>Mid-Century Inspired Office Chair</h2>
#     <p>This mid-century inspired office chair is part of a beautiful family of furniture that includes filing cabinets, desks, bookcases, and meeting tables. Constructed with a durable cast aluminum base featuring a modified nylon PA6/PA66 coating, the shell thickness measures 10 mm. The seat is made from HD36 foam, providing both comfort and support. Available in several shell color options and base finishes such as stainless steel, matte black, gloss white, or chrome, this chair can be customized with either plastic back and front upholstery (SWC-100) or full upholstery (SWC-110) in 10 fabric and 6 leather choices. The chair is also available without armrests or with 8 position PU armrests, making it suitable for both home and business settings.</p>
#     <p>Product IDs: SWC-100, SWC-110</p>
#
#     <h3>Product Dimensions</h3>
#     <table>
#         <tr>
#             <th>Dimension</th>
#             <th>Measurement (in inches)</th>
#         </tr>
#         <tr>
#             <td>Width</td>
#             <td>20.87"</td>
#         </tr>
#         <tr>
#             <td>Depth</td>
#             <td>20.08"</td>
#         </tr>
#         <tr>
#             <td>Height</td>
#             <td>31.50"</td>
#         </tr>
#         <tr>
#             <td>Seat Height</td>
#             <td>17.32"</td>
#         </tr>
#         <tr>
#             <td>Seat Depth</td>
#             <td>16.14"</td>
#         </tr>
#     </table>
# </div>
# ```
# ```html
# <div>
#     <h2>Mid-Century Inspired Office Chair</h2>
#     <p>This mid-century inspired office chair is part of a beautiful family of furniture that includes filing cabinets, desks, bookcases, and meeting tables. Constructed with a durable cast aluminum base featuring a modified nylon PA6/PA66 coating, the shell thickness measures 10 mm. The seat is made from HD36 foam, providing both comfort and support. Available in several shell color options and base finishes such as stainless steel, matte black, gloss white, or chrome, this chair can be customized with either plastic back and front upholstery (SWC-100) or full upholstery (SWC-110) in 10 fabric and 6 leather choices. The chair is also available without armrests or with 8 position PU armrests, making it suitable for both home and business settings.</p>
#     <p>Product IDs: SWC-100, SWC-110</p>
#
#     <h3>Product Dimensions</h3>
#     <table>
#         <tr>
#             <th>Dimension</th>
#             <th>Measurement (in inches)</th>
#         </tr>
#         <tr>
#             <td>Width</td>
#             <td>20.87"</td>
#         </tr>
#         <tr>
#             <td>Depth</td>
#             <td>20.08"</td>
#         </tr>
#         <tr>
#             <td>Height</td>
#             <td>31.50"</td>
#         </tr>
#         <tr>
#             <td>Seat Height</td>
#             <td>17.32"</td>
#         </tr>
#         <tr>
#             <td>Seat Depth</td>
#             <td>16.14"</td>
#         </tr>
#     </table>
# </div>
# ```
